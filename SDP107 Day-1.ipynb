# %%
#import to demonstate numpy library

import numpy as np
np.array([2,3]).ndim #.ndim returns dimension of array
# Out:
# 1

# %%
import pandas as pd

# %%
#Display Data in series form
s1=pd.Series([1,2,3,4])
s1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
#Check dtype of series
s1.dtype
# Out:
# dtype('int64')

# %%
#Change the index to custom type.
s1=pd.Series([1,2,3,4],index=[100,101,102,103])
print(s1)
#Change dtype of series
print()
s1=pd.Series([1,2,3,4],index=["A","B","C","D"],dtype=float)
print(s1)
# Out:
# 100    1
# 101    2
# 102    3
# 103    4
# dtype: int64
#
# A    1.0
# B    2.0
# C    3.0
# D    4.0
# dtype: float64

# %%
#DataFrame
data=[
    [1,2],
    [2,3],
]
pd.DataFrame(data,index=['ABC','DEF'],columns=["Maths",'Science'])
# Out:
#      Maths  Science
# ABC      1        2
# DEF      2        3

# %%
#Loading csv file
import pandas as pd
titanic=pd.read_csv("Datasets/titanic.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#Number of rows
len(titanic)
# Out:
# 418

# %%
#Get first 5 records from csv
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
#Get last 5 records from csv
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
#Get info about the csv file
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
#Describe() function
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
#Data accessing methods in pandas
print(titanic['Age'])

#accessing multiple data
titanic[['Age','Name','Survived']]
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64
#       Age                                          Name  Survived
# 0    34.5                              Kelly, Mr. James         0
# 1    47.0              Wilkes, Mrs. James (Ellen Needs)         1
# 2    62.0                     Myles, Mr. Thomas Francis         0
# 3    27.0                              Wirz, Mr. Albert         0
# 4    22.0  Hirvonen, Mrs. Alexander (Helga E Lindqvist)         1
# ..    ...                                           ...       ...
# 413   NaN                            Spector, Mr. Woolf         0
# 414  39.0                  Oliva y Ocana, Dona. Fermina         1
# 415  38.5                  Saether, Mr. Simon Sivertsen         0
# 416   NaN                           Ware, Mr. Frederick         0
# ...

# %%
#Display Custom records
#.loc[[row_label],[column_label]]
titanic.loc[[0,10,20],['Name','Age','Survived']]
# Out:
#                       Name   Age  Survived
# 0         Kelly, Mr. James  34.5         0
# 10        Ilieff, Mr. Ylio   NaN         0
# 20  Rothschild, Mr. Martin  55.0         0

# %%
#Display range of records using iloc()
#Slicing
titanic.iloc[0:5,-4:]
# Out:
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
#Filtering records based on data
#>50
#age>50 && female

titanic[titanic['Sex']=='female']

#Age > 50
t1=titanic[titanic['Age']>=50]

#Age>50 && female
t1[t1['Sex']=='female']

#or
titanic[(titanic['Age']>50) & (titanic['Sex']=='female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 48           940         1       1
# 69           961         1       1
# 77           969         1       1
# 96           988         1       1
# 114         1006         1       1
# 179         1071         1       1
# 213         1105         1       2
# 224         1116         1       1
# 240         1132         1       1
# 305         1197         1       1
# 314         1206         1       1
# 343         1235         1       1
# 356         1248         1       1
# 374         1266         1       1
# 391         1283         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 48     Bucknell, Mrs. William Robert (Emma Eliza Ward)  female  60.0      0
# 69                 Fortune, Mrs. Mark (Mary McDougald)  female  60.0      1
# 77   Cornell, Mrs. Robert Clifford (Malvina Helen L...  female  55.0      2
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
# ...

# %%
#Find unique values in dataset
print("Unique Values are:",titanic['Sex'].unique())
#Count amount of unique entry in column
print("Total count of entries:\n{}".format(titanic['Sex'].value_counts()))
# Out:
# Unique Values are: ['male' 'female']
# Total count of entries:
# male      266
# female    152
# Name: Sex, dtype: int64

# %%
#NULL values checking.
#Check all values are null in record
titanic.isnull()

#Display total sum of null values
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
titanic.drop('Cabin',axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#0,100,200
titanic.drop([0,100,200],0)
#Removed record 0,100,200
# Out:
# C:\Users\Anirudh PC\AppData\Local\Temp\ipykernel_13708\350535502.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   titanic.drop([0,100,200],0)
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# 5            897         0       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# ...

# %%
#Finding mean,median,mode
#Finding mean()
print("Mean of age:",titanic['Age'].mean())
#Finding median()
print("Median of age:",titanic['Age'].median())
#Finding mode()
print("Mode of age:\n{}".format(titanic['Age'].mode()))
# Out:
# Mean of age: 30.272590361445783
# Median of age: 27.0
# Mode of age:
# 0    21.0
# 1    24.0
# Name: Age, dtype: float64

# %%
# Day 1 Assignment. Check Age field for NULL values and clean the data
#Data Cleaning,checking missing, find percentage, drop those
x=titanic['Cabin'].isnull() # Retrieve info about which all are

print("Total records:",len(x))
print("Totla Null Records:",x.sum())
percentage=x.mean()
print("Percentage of null record:{0:.1f}%".format(percentage*100))

# Now remove the indexes whose values are null
titanic.drop('Cabin',1,inplace=True)
# 0 indicates rows, 1 indicates delete columns. 
# Basically 0 deletes tuple, 1 deletes only column.
# inplace=True defines that dropping affects the variable, False defines temporary change.
print("Dropped Values which had 'Cabin' as NULL values.")
# Out:
# Total records: 418
# Totla Null Records: 327
# Percentage of null record:78.2%
# Dropped Values which had 'Cabin' as NULL values.
# C:\Users\Anirudh PC\AppData\Local\Temp\ipykernel_13708\4042112522.py:11: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   titanic.drop('Cabin',1,inplace=True)

# %%
# Day 2 21-06-2023
titanic.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Ticket          0
# Fare            1
# Embarked        0
# dtype: int64

# %%
# Imputing the null 'Age' Value
titanic['Age']=titanic['Age'].fillna(titanic['Age'].mean())

# %%
titanic['Age'].isnull().sum()
# Out:
# 0

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Embarked       0
# dtype: int64

# %%
# Impute the Fare value.
# titanic["Fare"].dropna(inplace=True) <- drops all the null values of 'Fare'

print("Mean:",titanic['Fare'].mean(),"Median:",titanic['Fare'].median())

titanic["Fare"]=titanic['Fare'].fillna(titanic['Fare'].median())
print("Filled will median values")
print(titanic['Fare'].isnull().sum())
# Out:
# Mean: 35.57653540669856 Median: 14.4542
# Filled will median values
# 0

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
titanic.dropna(axis=1,how='any',inplace=True)

# %%
""" 
1. Data Collection
2. EDA(Explorative Data Analysis)
3. Preprocessing(Feature Engineering)
4. Building Model
5. Deployment
"""

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %pip install seaborn
import seaborn as sns
df=pd.read_csv('DataSets/titanic.csv')
df.head(2)
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S

# %%
sns.histplot(df.Age)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>
